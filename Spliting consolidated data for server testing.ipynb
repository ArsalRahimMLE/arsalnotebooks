# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('/home/arsal/Desktop/data/consolidated_data.csv' ,encoding='ISO-8859-1')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head(20)
# Out:
#                    Time             Security Policy Application Category  \
# 0   2018-11-13 22:45:49  local user internet policy     General_Internet
# 1   2018-11-13 22:45:49  local user internet policy     General_Internet
# 2   2018-11-13 22:45:49  local user internet policy     General_Internet
# 3   2018-11-13 22:45:49  local user internet policy     General_Internet
# 4   2018-11-13 22:45:49  local user internet policy     General_Internet
# 5   2018-11-13 22:45:49  local user internet policy     General_Internet
# 6   2018-11-13 22:45:49  local user internet policy              Network
# 7   2018-11-13 22:45:49  local user internet policy     General_Internet
# 8   2018-11-13 22:45:49  local user internet policy     General_Internet
# 9   2018-11-13 22:45:49  local user internet policy              Network
# 10  2018-11-13 22:45:49  local user internet policy     General_Internet
# 11  2018-11-13 22:45:49  local user internet policy     General_Internet
# ...

# %%
data.shape
# Out:
# (2261192, 27)

# %%
data.columns
# Out:
# Index(['Time', 'Security Policy', 'Application Category',
#        'Application Subcategory', 'Application', 'Protocol', 'URL',
#        'URL Category', 'URL Subcategory', ' Filtering Type', 'Profile',
#        'Virtural System', 'Domain Name', 'Action', 'Source Zone',
#        'Source Address', 'Source Region', 'Source User', 'Source Port',
#        'NAT Source Address', 'NAT Source Port', 'Destination Zone',
#        'Destination Address', 'Destination Region', 'Destination Port',
#        'NAT Destination Address', 'NAT Destination Port'],
#       dtype='object')

# %%
data.Time = pd.to_datetime(data.Time)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2261192 entries, 0 to 2261191
# Data columns (total 27 columns):
# Time                       datetime64[ns]
# Security Policy            object
# Application Category       object
# Application Subcategory    object
# Application                object
# Protocol                   object
# URL                        object
# URL Category               object
# URL Subcategory            object
#  Filtering Type            object
# Profile                    object
# Virtural System            object
# Domain Name                object
# Action                     object
# Source Zone                object
# Source Address             object
# Source Region              object
# Source User                object
# Source Port                int64
# NAT Source Address         object
# NAT Source Port            object
# Destination Zone           object
# Destination Address        object
# Destination Region         object
# ...

# %%
data.Time.min()
# Out:
# Timestamp('2018-11-13 22:45:49')

# %%
data.Time.max()
# Out:
# Timestamp('2018-11-25 23:59:59')

# %% [markdown]
# ### First split

# %%
dataset_1 = data.head(700000)

# %%
dataset_1.shape
# Out:
# (700000, 27)

# %% [markdown]
# ### Second split

# %%
dataset_2 = data.head(900000)

# %%
dataset_2.shape
# Out:
# (900000, 27)

# %% [markdown]
# ### Third split

# %%
dataset_3 = data.head(110000)

# %%
dataset_3.shape
# Out:
# (110000, 27)

# %% [markdown]
# ### Fourth split

# %%
# dataset_4 = data.head(500000)

# %%
# dataset_4.shape

# %% [markdown]
# ### Creating CSVs

# %%
dataset_1.to_csv('/home/arsal/Desktop/server_testing/7_lac.csv')

# %%
dataset_2.to_csv('/home/arsal/Desktop/server_testing/9_lac.csv')

# %%
dataset_3.to_csv('/home/arsal/Desktop/server_testing/11_lac.csv')

# %%
# dataset_4.to_csv('/home/arsal/Desktop/server_testing/dataset_4.csv')

# %%
dt_one = pd.read_csv('/home/arsal/Desktop/data/dt_one.csv' ,encoding='ISO-8859-1')

# %%
dt_one.shape
# Out:
# (1000000, 28)

# %%
dt_two = pd.read_csv('/home/arsal/Desktop/data/dt_two.csv' ,encoding='ISO-8859-1')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
dt_two.shape
# Out:
# (1261192, 28)

# %% [markdown]
# ## Creating training 18,00,000 and testing and testing 4,61,192

# %%
data.shape
# Out:
# (2261192, 27)

# %%
training = data.iloc[:1800000]
training
# Out:
#                         Time             Security Policy Application Category  \
# 0        2018-11-13 22:45:49  local user internet policy     General_Internet
# 1        2018-11-13 22:45:49  local user internet policy     General_Internet
# 2        2018-11-13 22:45:49  local user internet policy     General_Internet
# 3        2018-11-13 22:45:49  local user internet policy     General_Internet
# 4        2018-11-13 22:45:49  local user internet policy     General_Internet
# ...                      ...                         ...                  ...
# 1799995  2018-11-23 18:26:29  local user internet policy              Network
# 1799996  2018-11-23 18:26:29  local user internet policy              Network
# 1799997  2018-11-23 18:26:29  local user internet policy              Network
# 1799998  2018-11-23 18:26:29  local user internet policy              Network
# 1799999  2018-11-23 18:26:29  local user internet policy        Entertainment
#
# ...

# %%
training.to_csv('/home/arsal/Desktop/server_testing/training.csv')

# %%
testing = data.iloc[1800000:]
testing
# Out:
#                         Time             Security Policy Application Category  \
# 1800000  2018-11-23 18:26:29  local user internet policy     General_Internet
# 1800001  2018-11-23 18:26:29  local user internet policy              Network
# 1800002  2018-11-23 18:26:29  local user internet policy              Network
# 1800003  2018-11-23 18:26:29  local user internet policy              Network
# 1800004  2018-11-23 18:26:29  local user internet policy              Network
# ...                      ...                         ...                  ...
# 2261187  2018-11-25 23:59:59  local user internet policy     General_Internet
# 2261188  2018-11-25 23:59:59  local user internet policy     General_Internet
# 2261189  2018-11-25 23:59:59  local user internet policy     General_Internet
# 2261190  2018-11-25 23:59:59  local user internet policy     General_Internet
# 2261191  2018-11-25 23:59:59  local user internet policy              Network
#
# ...

# %%
testing.to_csv('/home/arsal/Desktop/server_testing/testing.csv')

# %% [markdown]
# ## Making some changes in training

# %%
train_dt = pd.read_csv('/home/arsal/Desktop/server_testing/training.csv')
train_dt.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Unnamed: 0                 Time             Security Policy  \
# 0           0  2018-11-13 22:45:49  local user internet policy
# 1           1  2018-11-13 22:45:49  local user internet policy
# 2           2  2018-11-13 22:45:49  local user internet policy
# 3           3  2018-11-13 22:45:49  local user internet policy
# 4           4  2018-11-13 22:45:49  local user internet policy
#
#   Application Category Application Subcategory     Application Protocol  \
# 0     General_Internet         Network_Storage        AmazonS3      TCP
# 1     General_Internet         Network_Storage        AmazonS3      TCP
# 2     General_Internet          Search_Engines  Google_Service      TCP
# ...

# %%
train_dt.drop(columns=['Unnamed: 0'], inplace=True)

# %%
train_dt.head()
# Out:
#                   Time             Security Policy Application Category  \
# 0  2018-11-13 22:45:49  local user internet policy     General_Internet
# 1  2018-11-13 22:45:49  local user internet policy     General_Internet
# 2  2018-11-13 22:45:49  local user internet policy     General_Internet
# 3  2018-11-13 22:45:49  local user internet policy     General_Internet
# 4  2018-11-13 22:45:49  local user internet policy     General_Internet
#
#   Application Subcategory     Application Protocol  \
# 0         Network_Storage        AmazonS3      TCP
# 1         Network_Storage        AmazonS3      TCP
# 2          Search_Engines  Google_Service      TCP
# 3            Web_Browsing       Adobe_Com      TCP
# 4          Search_Engines  Google_Service      TCP
#
#                                                  URL            URL Category  \
# 0           detectportal.firefox.com/.../*uccess.txt  Information Technology
# ...

# %%
train_dt.columns
# Out:
# Index(['Time', 'Security Policy', 'Application Category',
#        'Application Subcategory', 'Application', 'Protocol', 'URL',
#        'URL Category', 'URL Subcategory', ' Filtering Type', 'Profile',
#        'Virtural System', 'Domain Name', 'Action', 'Source Zone',
#        'Source Address', 'Source Region', 'Source User', 'Source Port',
#        'NAT Source Address', 'NAT Source Port', 'Destination Zone',
#        'Destination Address', 'Destination Region', 'Destination Port',
#        'NAT Destination Address', 'NAT Destination Port'],
#       dtype='object')

# %%
len(train_dt[train_dt['URL Subcategory']=='Leisure Sports'])
# Out:
# 198

# %%
train_dt[train_dt['URL Subcategory']=='Leisure Sports']
# Out:
#                         Time             Security Policy Application Category  \
# 53057    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53059    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53073    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53075    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53079    2018-11-13 23:19:40  local user internet policy     General_Internet
# ...                      ...                         ...                  ...
# 1679395  2018-11-22 23:58:04  local user internet policy        Entertainment
# 1796690  2018-11-23 18:25:13  local user internet policy     General_Internet
# 1796691  2018-11-23 18:25:13  local user internet policy     General_Internet
# 1796712  2018-11-23 18:25:13  local user internet policy     General_Internet
# 1796713  2018-11-23 18:25:13  local user internet policy     General_Internet
#
# ...

# %%
len(train_dt[train_dt['URL Subcategory']=='Gambling'])
# Out:
# 128

# %%
train_dt[train_dt['URL Subcategory']=='Gambling']
# Out:
#                         Time             Security Policy Application Category  \
# 252674   2018-11-15 22:01:04  local user internet policy     General_Internet
# 252679   2018-11-15 22:01:04  local user internet policy     General_Internet
# 383662   2018-11-15 23:29:23  local user internet policy     General_Internet
# 383666   2018-11-15 23:29:23  local user internet policy     General_Internet
# 462797   2018-11-16 23:05:46  local user internet policy     General_Internet
# ...                      ...                         ...                  ...
# 1456472  2018-11-21 23:38:50  local user internet policy     General_Internet
# 1562707  2018-11-22 22:32:45  local user internet policy     General_Internet
# 1562710  2018-11-22 22:32:45  local user internet policy     General_Internet
# 1748787  2018-11-23 18:05:04  local user internet policy     General_Internet
# 1748799  2018-11-23 18:05:04  local user internet policy     General_Internet
#
# ...

# %%
train_dt['URL Subcategory'] = train_dt['URL Subcategory'].apply(lambda x: 'Gambling' if x == 'Leisure Sports' else x)

# %%
len(train_dt[train_dt['URL Subcategory']=='Gambling'])
# Out:
# 326

# %%
train_dt[train_dt['URL Subcategory']=='Leisure Sports']
# Out:
# Empty DataFrame
# Columns: [Time, Security Policy, Application Category, Application Subcategory, Application, Protocol, URL, URL Category, URL Subcategory,  Filtering Type, Profile, Virtural System, Domain Name, Action, Source Zone, Source Address, Source Region, Source User, Source Port, NAT Source Address, NAT Source Port, Destination Zone, Destination Address, Destination Region, Destination Port, NAT Destination Address, NAT Destination Port]
# Index: []
#
# [0 rows x 27 columns]

# %%
train_dt[(train_dt['URL Category']=='Sports') & (train_dt['URL Subcategory']=='Gambling')]
# Out:
#                         Time             Security Policy Application Category  \
# 53057    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53059    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53073    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53075    2018-11-13 23:19:39  local user internet policy     General_Internet
# 53079    2018-11-13 23:19:40  local user internet policy     General_Internet
# ...                      ...                         ...                  ...
# 1679395  2018-11-22 23:58:04  local user internet policy        Entertainment
# 1796690  2018-11-23 18:25:13  local user internet policy     General_Internet
# 1796691  2018-11-23 18:25:13  local user internet policy     General_Internet
# 1796712  2018-11-23 18:25:13  local user internet policy     General_Internet
# 1796713  2018-11-23 18:25:13  local user internet policy     General_Internet
#
# ...

# %%
train_dt.to_csv('/home/arsal/Desktop/server_testing/train_new.csv')

# %% [markdown]
# ## Getting unique URL subcategory

# %%
unique_urls_subcategories = pd.DataFrame(np.unique(data['URL Subcategory']), columns=['URL_SubCategory'])

# %%
unique_urls_subcategories.to_csv('/home/arsal/Desktop/URL_SubCategory.csv')
