# %%
import pandas as pd

# %%
data = pd.read_csv('/home/arsal/Data/crap.csv')

# %%
data
# Out:
#    Pack  Size  Age
# 0   2.0   8.0
# 1   NaN   NaN  NaN
# 2   3.0   NaN    5
# 3   4.0  52.0    5
# 4   2.0   5.0    6

# %%
total_charges_filter = data.Age == " "

# %%
total_charges_filter
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Age, dtype: bool

# %%
data = data[~total_charges_filter]
data.TotalCharges = pd.to_numeric(data.Age)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access

# %%
data
# Out:
#    Pack  Size  Age
# 1   NaN   NaN  NaN
# 2   3.0   NaN    5
# 3   4.0  52.0    5
# 4   2.0   5.0    6

# %%
data = data.dropna(how="all")

# %%
data
# Out:
#    Pack  Size Age
# 2   3.0   NaN   5
# 3   4.0  52.0   5
# 4   2.0   5.0   6

# %%
data = pd.read_csv('/home/arsal/Desktop/Time Series Data/Reduced Cleaned Datasets/KSE.csv')

# %%
data.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
data
# Out:
#             Date   Index      Open      High       Low     Close  KSE_Return
# 0     1998-07-01  KSE100    879.61    904.79    844.58    863.16      0.0000
# 1     1998-07-02  KSE100    863.16    881.95    839.88    878.17      0.0174
# 2     1998-07-03  KSE100    878.17    890.44    860.63    867.83     -0.0118
# 3     1998-07-04  KSE100    867.83    893.76    858.21    885.78      0.0207
# 4     1998-07-05  KSE100    867.83    893.76    858.21    885.78      0.0000
# 5     1998-07-06  KSE100    867.83    893.76    858.21    885.78      0.0000
# 6     1998-07-07  KSE100    885.78    905.51    866.45    866.71     -0.0215
# 7     1998-07-08  KSE100    885.78    905.51    866.45    866.71      0.0000
# 8     1998-07-09  KSE100    866.71    869.59    824.20    833.00     -0.0389
# 9     1998-07-10  KSE100    833.00    833.00    748.03    777.26     -0.0669
# 10    1998-07-11  KSE100    777.26    789.66    759.94    774.73     -0.0033
# ...

# %%
data2 = pd.read_csv('/home/arsal/Desktop/Time Series Data/Initial Raw Data downloaded from web/KSE.csv')

# %%
data2
# Out:
#             Date   Index      Open      High       Low     Close     Turnover  \
# 0     11/17/2017  KSE100  40813.31  40910.76  40637.87  40844.40   58018690.0
# 1     11/16/2017  KSE100  40662.79  40885.65  40662.79  40813.31   51544410.0
# 2     11/15/2017  KSE100  40943.78  40943.78  40592.77  40662.79   47870700.0
# 3     11/14/2017  KSE100  41239.89  41317.43  40899.99  40943.78   57486520.0
# 4     11/13/2017  KSE100  41435.70  41440.36  41141.52  41239.89   34164780.0
# 5     11/10/2017  KSE100  41790.16  41836.35  41390.38  41435.70   54435250.0
# 6      11/9/2017  KSE100  41259.16  41850.56  41259.16  41790.16   78829710.0
# 7      11/8/2017  KSE100  41049.22  41293.99  40967.72  41259.16   57218800.0
# 8      11/7/2017  KSE100  41030.77  41262.45  41004.38  41049.22   53266560.0
# 9      11/6/2017  KSE100  41064.00  41232.66  40928.27  41030.77   45748770.0
# 10     11/3/2017  KSE100  40498.87  41127.44  40449.97  41064.00   60903140.0
# ...

# %%
import statsmodels.api as stat
import statsmodels.tsa.stattools as ts
import quandl
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data1 = quandl.get("CHRIS/MCX_AL1", start_date="2016-11-01", api_key='U_PJwA55r5u8Lz_uFJ6L')
data2 = quandl.get("CHRIS/MCX_PB1", start_date="2016-11-01", api_key='U_PJwA55r5u8Lz_uFJ6L')

# %%
data1 #almunium
# Out:
#               Open    High     Low   Close  Volume  Open Interest
# Date
# 2016-11-01  115.65  116.15  114.70  115.55  6196.0         6650.0
# 2016-11-02  114.80  115.15  113.50  114.65  8347.0         6481.0
# 2016-11-04  115.00  115.45  114.40  114.75  5162.0         6600.0
# 2016-11-07  116.00  116.50  114.25  115.15  6322.0         6062.0
# 2016-11-08  115.15  115.25  113.75  114.80  6749.0         5452.0
# ...            ...     ...     ...     ...     ...            ...
# 2019-07-30  138.55  139.30  137.85  138.35   183.0          541.0
# 2019-07-31  141.50  141.90  140.15  140.35  3093.0         2557.0
# 2019-08-01  140.45  140.55  138.70  138.95  2909.0         2653.0
# 2019-08-02  139.00  140.30  138.90  139.65  3767.0         2432.0
# 2019-08-05  139.40  141.50  139.40  141.20  2797.0         2347.0
#
# [677 rows x 6 columns]

# %%
data2 #lead
# Out:
#               Open    High     Low   Close   Volume  Open Interest
# Date
# 2016-11-01  138.30  138.85  136.75  138.00  12962.0         4407.0
# 2016-11-02  137.40  137.80  136.35  137.60  12194.0         4617.0
# 2016-11-04  138.75  140.20  138.30  139.75  10326.0         4849.0
# 2016-11-07  140.40  141.40  138.30  139.75  15924.0         4605.0
# 2016-11-08  139.90  141.60  138.10  140.85  15908.0         4388.0
# ...            ...     ...     ...     ...      ...            ...
# 2019-07-30  158.45  158.90  152.70  153.80    290.0           45.0
# 2019-07-31  153.00  154.70  152.00  154.05   8695.0         1281.0
# 2019-08-01  153.50  153.50  151.60  152.15   7705.0         1392.0
# 2019-08-02  151.50  152.45  150.20  151.50   7789.0         1472.0
# 2019-08-05  151.65  154.85  151.65  154.30   8816.0         1311.0
#
# [677 rows x 6 columns]

# %% [markdown]
# ## New Work

# %%
import pandas as pd

# %%
dt = pd.read_csv('/')
dt = pd.read_excel('/')
