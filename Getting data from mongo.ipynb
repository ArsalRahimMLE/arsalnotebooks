# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient()
db = client['iponym_development']
collection = db.csv_store
data = pd.DataFrame(list(collection.find()))

# %%
data
# Out:
#        Filtering Type Action          Application Application Category  \
# 0         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 1         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 2         Pre-defined  Alert        microsoft.com     General_Internet
# 3         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 4         Pre-defined  Alert       Google_Service     General_Internet
# 5         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 6         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 7         Pre-defined  Alert  Apple_Certification     General_Internet
# 8         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 9         Pre-defined  Alert      IOS_PushMessage     General_Internet
# 10        Pre-defined  Alert        microsoft.com     General_Internet
# 11        Pre-defined  Alert       Google_Service     General_Internet
# ...

# %%
data.columns
# Out:
# Index([' Filtering Type', 'Action', 'Application', 'Application Category',
#        'Application Subcategory', 'Destination Address', 'Destination Port',
#        'Destination Region', 'Destination Zone', 'Domain Name',
#        'NAT Destination Address', 'NAT Destination Port', 'NAT Source Address',
#        'NAT Source Port', 'Profile', 'Protocol', 'Security Policy',
#        'Source Address', 'Source Port', 'Source Region', 'Source User',
#        'Source Zone', 'Time', 'Time_ending', 'URL', 'URL Category',
#        'URL Subcategory', 'Virtural System', '_id', 'duration', 'index',
#        'session_count', 'session_duration'],
#       dtype='object')

# %%
data.to_csv(r'/home/arsal/Desktop/data_csv.csv')
